# %% [markdown]
# <a href="https://colab.research.google.com/github/isdeniz/msc-2024/blob/main/llama3_nlbse22_summary_and_preds_with_70b_and_8b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !python3.10 -m pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.6/990.6 kB 53.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.0/384.0 kB 32.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 13.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# !python3.10 -m pip install langchain-core

# %%
# !python3.10 -m pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 84.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from langchain_community.llms import Ollama
llm = Ollama(model = "llama3", num_ctx=8192, temperature=0)

# %%
pip install tqdm

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
test_sample = pd.read_pickle('data/nlbse22_test_sample_summarized_llama3_70b_preds.pkl')
print('Number of issues: ', test_sample.shape)
# Out:
# Number of issues:  (19, 29)

# %%
test_sample.head()
# Out:
#       index                               original_issue_title  \
# 1076  48736                    [gui] Clang-Tidy Clazy Warnings
# 1339   1975                              微信小程序端渲染的时候，有的文章图片不展示
# 1423  17453  from the cloud about adding cleaning. try unde...
# 1957  39588                                      ufuzz failure
# 2492  22018                   Thank you message not displaying
#
#                                      preprocessed_title  \
# 1076                      gui clang tidy clazy warnings
# 1339                                                NaN
# 1423  from the cloud about adding cleaning. try unde...
# 1957                                      ufuzz failure
# 2492                   thank you message not displaying
#
#                                     original_issue_body  \
# 1076  ```\r\n/opt/root_src/gui/browsable/src/RProvid...
# 1339  <!--注意：提问前请确认已经在文档中查找过没有相关资料或文档没有描述清楚-->\r\n\r...
# 1423  Hibernate:\r\nJan 28 04:27:42 ip-172-31-32-174...
# ...

# %%
with tqdm(total=test_sample.shape[0], ncols=100) as pbar:
    for idx in test_sample.index:
        try:
            test_sample.loc[idx, 'llama3_8b_prediction_round2'] = llm.invoke(f"""Classify the following issue as "bug", "enhancement", "question" or "other" and rate your classification confidence and issue understandability in range 0 - 100. Your answer should only include:
Classification: your classification answer
Prediction Confidence: your level of confidence
Issue Understandability: level of understandability
Do not provide any explanation.
Issue Title: {test_sample.loc[idx,'original_issue_title']}
Issue Body: {test_sample.loc[idx,'llama3_70b_body_summary_corrected']}
""")
            pbar.update(1)
        except Exception as e:
            print(f'Exception at index {idx}: {e}')
            continue

print(f'Categorization of {test_sample.shape[0]} issues is complete')
# Out:
# 100%|███████████████████████████████████████████████████████████████| 19/19 [00:11<00:00,  1.66it/s]
# Categorization of 19 issues is complete

# %%
test_sample['llama3_8b_prediction_round2'].value_counts()
# Out:
# llama3_8b_prediction_round2
# Classification: bug\nPrediction Confidence: 80\nIssue Understandability: 90            7
# Classification: enhancement\nPrediction Confidence: 80\nIssue Understandability: 90    3
# Classification: question\nPrediction Confidence: 80\nIssue Understandability: 90       3
# Classification: Bug\nPrediction Confidence: 80\nIssue Understandability: 90            2
# Classification: enhancement\nPrediction Confidence: 20\nIssue Understandability: 80    1
# Classification: bug\nPrediction Confidence: 90\nIssue Understandability: 100           1
# Classification: question\nPrediction Confidence: 100\nIssue Understandability: 0       1
# Classification: bug\nPrediction Confidence: 90\nIssue Understandability: 95            1
# Name: count, dtype: int64

# %%
test_sample.to_pickle('nlbse22_test_sample_summarized_llama3_70b_and_8b_preds.pkl')
